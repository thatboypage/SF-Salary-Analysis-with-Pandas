# %% [markdown]
# # SF Salary Analysis

# %% [markdown]
# ## 1. Import the Salaries dataset and load the dependencies

# %%
import pandas as pd

# %%
# Loading the Dataset
salary_data = pd.read_csv('Salaries.csv')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_4616\2291160692.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   salary_data = pd.read_csv('Salaries.csv')

# %%
# 2.	Display the top 5 rows of the dataset
salary_data.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# ...

# %%
# 3.	Check the last 5 rows of the dataset
salary_data.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      NaN
# 148651  148652   Not provided                Not provided      NaN
# 148652  148653   Not provided                Not provided      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency Status
# 148649    NaN  San Francisco     PT
# 148650    NaN  San Francisco    NaN
# ...

# %%
# 4.	Find the shape of the dataset (Number of rows and columns)
salary_data.shape
# Out:
# (148654, 13)

# %%
print(f'The number of rows is {salary_data.shape[0]} and {salary_data.shape[1]} columns')
# Out:
# The number of rows is 148654 and 13 columns

# %%
# 5.	Get Information about the dataset
salary_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(7), int64(2), object(4)
# memory usage: 14.7+ MB

# %%
# 6.	Check Null values in the dataset
salary_data.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
# 7.	Drop Id, Notes, Agency and Status
salary_data.drop(['Agency', 'Id', 'Notes', 'Status'], axis = 1, inplace = True)

# %%
salary_data.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
# 8.	Get the overall statistics about the data frame
salary_data.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       Benefits  \
# count  148045.000000  148650.000000  148650.000000  112491.000000
# mean    66325.448841    5066.059886    3648.767297   25007.893151
# std     42764.635495   11454.380559    8056.601866   15402.215858
# min      -166.010000      -0.010000   -7058.590000     -33.890000
# 25%     33588.200000       0.000000       0.000000   11535.395000
# 50%     65007.450000       0.000000     811.270000   28628.620000
# 75%     94691.050000    4658.175000    4236.065000   35566.855000
# max    319275.010000  245131.880000  400184.250000   96570.660000
#
#             TotalPay  TotalPayBenefits           Year
# count  148654.000000     148654.000000  148654.000000
# mean    74768.321972      93692.554811    2012.522643
# std     50517.005274      62793.533483       1.117538
# min      -618.130000       -618.130000    2011.000000
# 25%     36168.995000      44065.650000    2012.000000
# ...

# %%
# Transposing of Data
salary_data.describe().T
# Out:
#                      count          mean           std      min        25%  \
# BasePay           148045.0  66325.448841  42764.635495  -166.01  33588.200
# OvertimePay       148650.0   5066.059886  11454.380559    -0.01      0.000
# OtherPay          148650.0   3648.767297   8056.601866 -7058.59      0.000
# Benefits          112491.0  25007.893151  15402.215858   -33.89  11535.395
# TotalPay          148654.0  74768.321972  50517.005274  -618.13  36168.995
# TotalPayBenefits  148654.0  93692.554811  62793.533483  -618.13  44065.650
# Year              148654.0   2012.522643      1.117538  2011.00   2012.000
#
#                        50%         75%        max
# BasePay           65007.45   94691.050  319275.01
# OvertimePay           0.00    4658.175  245131.88
# OtherPay            811.27    4236.065  400184.25
# Benefits          28628.62   35566.855   96570.66
# TotalPay          71426.61  105839.135  567595.43
# TotalPayBenefits  92404.09  132876.450  567595.43
# ...

# %%
# 9.	Find Occurrence of the Employee Name (Top 5)

salary_data.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
salary_data['EmployeeName'].value_counts().head()
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %%
# 10.	Find the number of the Unique Job title

salary_data.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
salary_data['JobTitle'].nunique()
# Out:
# 2159

# %%
# 11.	Total Number of Job titles that contain captain

salary_data['JobTitle']
# Out:
# 0         GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                        CAPTAIN III (POLICE DEPARTMENT)
# 2                        CAPTAIN III (POLICE DEPARTMENT)
# 3                   WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4           DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#                                ...
# 148649                                         Custodian
# 148650                                      Not provided
# 148651                                      Not provided
# 148652                                      Not provided
# 148653                        Counselor, Log Cabin Ranch
# Name: JobTitle, Length: 148654, dtype: object

# %%
salary_data['JobTitle'].str.contains('CAPTAIN', case = False)
# Out:
# 0         False
# 1          True
# 2          True
# 3         False
# 4         False
#           ...
# 148649    False
# 148650    False
# 148651    False
# 148652    False
# 148653    False
# Name: JobTitle, Length: 148654, dtype: bool

# %%
salary_data[salary_data['JobTitle'].str.contains('CAPTAIN', case = False)]
# Out:
#               EmployeeName                               JobTitle    BasePay  \
# 1             GARY JIMENEZ        CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2           ALBERT PARDINI        CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 11        PATRICIA JACKSON        CAPTAIN III (POLICE DEPARTMENT)   99722.00
# 17          SEBASTIAN WONG  CAPTAIN, EMERGENCYCY MEDICAL SERVICES  140546.87
# 22           GEORGE GARCIA              CAPTAIN, FIRE SUPPRESSION  140546.88
# ...                    ...                                    ...        ...
# 116604   Gregory L Stewart              Captain, Fire Suppression   73355.21
# 120867     Michael J Moran                              Captain 3    7660.00
# 122361  Michael V Rolovich              Captain, Fire Suppression       0.00
# 126588    Stephen M Tittel                              Captain 3   68491.89
# 132232     Jeanne M Seyler              Captain, Fire Suppression   61039.43
#
# ...

# %%
len(salary_data[salary_data['JobTitle'].str.contains('CAPTAIN', case = False)])
# Out:
# 552

# %%
# 12.	Display all the Employee from the Fire Dept

salary_data[salary_data['JobTitle'].str.contains('FIRE', case = False)]
# Out:
#               EmployeeName                                          JobTitle  \
# 4          PATRICK GARDNER      DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 6                ALSON LEE                BATTALION CHIEF, (FIRE DEPARTMENT)
# 8           MICHAEL MORRIS                BATTALION CHIEF, (FIRE DEPARTMENT)
# 9       JOANNE HAYES-WHITE            CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 10           ARTHUR KENNEY  ASSISTANT CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# ...                    ...                                               ...
# 145956    Kenneth C Farris                                       Firefighter
# 147556       Edward A Dunn                                       Firefighter
# 148021      Kari A Johnson                                       Firefighter
# 148209        Sheryl K Lee                                       Firefighter
# 148554     Lawrence F Gatt                             Fire Alarm Dispatcher
#
# ...

# %%
salary_data[salary_data['JobTitle'].str.contains('FIRE', case = False)][['EmployeeName']]
# Out:
#               EmployeeName
# 4          PATRICK GARDNER
# 6                ALSON LEE
# 8           MICHAEL MORRIS
# 9       JOANNE HAYES-WHITE
# 10           ARTHUR KENNEY
# ...                    ...
# 145956    Kenneth C Farris
# 147556       Edward A Dunn
# 148021      Kari A Johnson
# 148209        Sheryl K Lee
# 148554     Lawrence F Gatt
#
# [5879 rows x 1 columns]

# %%
# 13.	Find Minimum, Maximum and Average Base Pay

minimum_base_pay = salary_data['BasePay'].min()
maximum_base_pay = salary_data['BasePay'].max()
average_base_pay = salary_data['BasePay'].mean()

# %%
print('minimum_base_pay', minimum_base_pay)
print('maximum_base_pay', maximum_base_pay)
print('average_base_pay', average_base_pay)
# Out:
# minimum_base_pay -166.01
# maximum_base_pay 319275.01
# average_base_pay 66325.44884050643

# %%
# 14.	Replace the ‘Not Provided’ in Employee Name column to NaN

salary_data.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
salary_data[salary_data['EmployeeName'] == 'Not Provided']
# Out:
#        EmployeeName                                 JobTitle   BasePay  \
# 13797  Not Provided  PUBLIC SAFETY COMMUNICATIONS DISPATCHER  57963.39
# 44151  Not Provided                   Public SafetyComm Disp  82196.52
#
#        OvertimePay  OtherPay  Benefits   TotalPay  TotalPayBenefits  Year
# 13797     19683.91   4373.86       NaN   82021.16          82021.16  2011
# 44151     25934.20   3752.49   38024.3  111883.21         149907.51  2012

# %%
salary_data['EmployeeName'].replace('Not Provided', 'NaN')
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650         Not provided
# 148651         Not provided
# 148652         Not provided
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
salary_data['EmployeeName'] = salary_data['EmployeeName'].replace('Not provided', 'NaN')
salary_data['EmployeeName'] = salary_data['EmployeeName'].replace('Not Provided', 'NaN')

# %%
salary_data['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
# 15.	Drop the Rows having missing values above 5 - Comeback to this

salary_data.isnull().sum()

# %%
# 16.	Find the Job Title of Albert Pardini

salary_data[salary_data['EmployeeName'] == ('Albert Pardini')]
# Out:
#          EmployeeName   JobTitle    BasePay  OvertimePay  OtherPay  Benefits  \
# 36519  Albert Pardini  Captain 3  196265.04          0.0  11404.04  46326.21
#
#         TotalPay  TotalPayBenefits  Year
# 36519  207669.08         253995.29  2012

# %%
salary_data[salary_data['EmployeeName'] == ('Albert Pardini')]['JobTitle']
# Out:
# 36519    Captain 3
# Name: JobTitle, dtype: object

# %%
# 17.	How much does Albert Pardini make (include benefit)?

salary_data[salary_data['EmployeeName'] == ('Albert Pardini')]
# Out:
#          EmployeeName   JobTitle    BasePay  OvertimePay  OtherPay  Benefits  \
# 36519  Albert Pardini  Captain 3  196265.04          0.0  11404.04  46326.21
#
#         TotalPay  TotalPayBenefits  Year
# 36519  207669.08         253995.29  2012

# %%
salary_data[salary_data['EmployeeName'] == ('Albert Pardini')][['TotalPayBenefits']]
# Out:
#        TotalPayBenefits
# 36519         253995.29

# %%
# 18.	Display Name of the Person having the highest Base Pay

salary_data[salary_data['BasePay'] == salary_data['BasePay'].max()]
# Out:
#          EmployeeName         JobTitle    BasePay  OvertimePay  OtherPay  \
# 72925  Gregory P Suhr  Chief of Police  319275.01          0.0  20007.06
#
#        Benefits   TotalPay  TotalPayBenefits  Year
# 72925  86533.21  339282.07         425815.28  2013

# %%
salary_data[salary_data['BasePay'] == salary_data['BasePay'].max()]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %%
salary_data.Year.unique()
# Out:
# array([2011, 2012, 2013, 2014], dtype=int64)

# %%
# 19.	Find the Average Base Pay of all employee per year

salary_data.groupby('Year')['BasePay'].mean()
# Out:
# Year
# 2011    63595.956517
# 2012    65436.406857
# 2013    69630.030216
# 2014    66564.421924
# Name: BasePay, dtype: float64

# %%
# 20.	Find the average Base Pay of all employee per Job Title

salary_data.groupby('JobTitle')['BasePay'].mean()
# Out:
# JobTitle
# ACCOUNT CLERK                                     43300.806506
# ACCOUNTANT                                        46643.172000
# ACCOUNTANT INTERN                                 28732.663958
# ACPO,JuvP, Juv Prob (SFERS)                       62290.780000
# ACUPUNCTURIST                                     66374.400000
#                                                       ...
# X-RAY LABORATORY AIDE                             47664.773077
# X-Ray Laboratory Aide                             46086.387100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    52609.910000
# Youth Comm Advisor                                39077.957500
# ZOO CURATOR                                       43148.000000
# Name: BasePay, Length: 2159, dtype: float64

# %%
# 21.	Find the Average Base Pay of Employee having Job Title Accountant

salary_data[salary_data['JobTitle'].str.contains('ACCOUNTANT', case = False)]
# Out:
#               EmployeeName                   JobTitle    BasePay  OvertimePay  \
# 7444       VICTORIA SANTOS  SENIOR SYSTEMS ACCOUNTANT  107382.02          0.0
# 7686           CAROLYN LEW  SENIOR SYSTEMS ACCOUNTANT  109158.60          0.0
# 7687              KAN HTUN  SENIOR SYSTEMS ACCOUNTANT  109158.06          0.0
# 8158           EDUARDO LIM  SENIOR SYSTEMS ACCOUNTANT  106492.07          0.0
# 8162    FLORDELIZA LEVISTE  SENIOR SYSTEMS ACCOUNTANT  106492.04          0.0
# ...                    ...                        ...        ...          ...
# 143492     Theodore N Wong              Accountant IV   12019.62          0.0
# 143766   Victoria L Santos              Accountant IV   10966.80          0.0
# 144811   Violeta M Mosuela              Accountant II    7836.41          0.0
# 146288           Dee P Ngo             Accountant III    3087.00          0.0
# 148174         Evan J Chan             Accountant III       0.00          0.0
#
# ...

# %%
salary_data[salary_data['JobTitle'].str.contains('ACCOUNTANT', case = False)]['BasePay'].mean()
# Out:
# 72245.57241071426

# %%
# 22.	Find the top 5 most common Jobs

salary_data.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
salary_data['JobTitle'].value_counts()
# Out:
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
salary_data['JobTitle'].value_counts().head()
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64
